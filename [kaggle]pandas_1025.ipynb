# %% [markdown]
# <a href="https://colab.research.google.com/github/topchaebol/kaggle/blob/main/%5Bkaggle%5Dpandas_1025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.DataFrame({'YES':[10,20,30],'NO':[40,50,60]})
# Out:
#    YES  NO
# 0   10  40
# 1   20  50
# 2   30  60

# %%
pd.DataFrame({'Mok': ['Sex', 'Money'], 'Sue': ['Pretty.', 'Bland.']})
# Out:
#      Mok      Sue
# 0    Sex  Pretty.
# 1  Money   Bland.

# %%
pd.DataFrame({'Bob': ['Sex.', 'Money.'],
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product 1', 'Product 2'])
# Out:
#               Bob           Sue
# Product 1    Sex.  Pretty good.
# Product 2  Money.        Bland.

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64
